# %% [markdown]
# <a href="https://colab.research.google.com/github/SaPahlavani/Exercise.Vision/blob/main/Exercise_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# تصویر یک فرد دلخواه را لود کنید، سپس با نمایش دادن از طریق<br>
# matplotlib<br>
#  و مشاهده‌ی اعداد محور مختصات، قسمت مربوط به چهره را فقط ببریدو در یک فایل جدید ذخیره کنید.

# %% [markdown]
# #Samanehahlavani
# exercise1

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys
print(sys.executable)
# Out:
# /usr/bin/python3

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
print (cv2.__version__)
# Out:
# 4.10.0

# %%
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread("/content/drive/MyDrive/images/samaneh.jpg")

# %%
# Display the image using cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=460x460>

# %%
print(type(image))
# Out:
# <class 'numpy.ndarray'>

# %%
print(image.shape)
# Out:
# (460, 460, 3)

# %%
print ('Height of Image:', int(image.shape[0]), 'pixels')
print ('Width of Image: ', int(image.shape[1]), 'pixels')
# Out:
# Height of Image: 460 pixels
# Width of Image:  460 pixels

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)#[:,:,::-1]

# %%
plt.imshow(image)

# %%
croppedImage = image[130:290 , 120:240 ]

# %%
cv2_imshow(croppedImage)
# Out:
# <PIL.Image.Image image mode=RGB size=120x160>

# %%
cv2.imwrite("samaneh.png", croppedImage)
# Out:
# True

# %%
current_directory = os.getcwd()  # مسیر پوشه کاری جاری
print("Current working directory:", current_directory)
# Out:
# Current working directory: /content

# %%
print(croppedImage.shape)
# Out:
# (160, 120, 3)

# %%
from math import floor

# %%
cropeed2 = image[image.shape[0]//3 : floor(2.7*image.shape[0]//4),
                 image.shape[1]//3 : floor(2.6*image.shape[1]//4)]

# %%
cv2_imshow(cropeed2)
# Out:
# <PIL.Image.Image image mode=RGB size=146x157>
